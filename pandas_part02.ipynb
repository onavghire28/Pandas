# %%
import pandas as pd
import numpy as np

# %%
#creating data frame using list

student_data = [["Om",78,"Nashik"],["Ayush",78,"Ozar"],["Pratham",49,'Pune']]

df = pd.DataFrame(student_data, columns = ['Name','Marks','Address'])
df
# Out:
#       Name  Marks Address
# 0       Om     78  Nashik
# 1    Ayush     78    Ozar
# 2  Pratham     49    Pune

# %%
#using dictonary

student_data = {
    "Name": ["Om","Ayush","Pratham"],
    "Marks":[90,75,46],
    "Address":["Ozar","Pune",'Nashik']
}

df = pd.DataFrame(student_data)
df
# Out:
#       Name  Marks Address
# 0       Om     90    Ozar
# 1    Ayush     75    Pune
# 2  Pratham     46  Nashik

# %%
#USing read_csv

movie = pd.read_csv("C:/Users/Om/Downloads/ipl-matches.csv")
movie
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
#Attributes and method

movie.shape
# Out:
# (950, 20)

# %%
movie.dtypes
# Out:
# ID                   int64
# City                object
# Date                object
# Season              object
# MatchNumber         object
# Team1               object
# Team2               object
# Venue               object
# TossWinner          object
# TossDecision        object
# SuperOver           object
# WinningTeam         object
# WonBy               object
# Margin             float64
# method              object
# Player_of_Match     object
# Team1Players        object
# Team2Players        object
# Umpire1             object
# Umpire2             object
# dtype: object

# %%
#Index
movie.index
# Out:
# RangeIndex(start=0, stop=950, step=1)

# %%
#Columns
movie.columns
# Out:
# Index(['ID', 'City', 'Date', 'Season', 'MatchNumber', 'Team1', 'Team2',
#        'Venue', 'TossWinner', 'TossDecision', 'SuperOver', 'WinningTeam',
#        'WonBy', 'Margin', 'method', 'Player_of_Match', 'Team1Players',
#        'Team2Players', 'Umpire1', 'Umpire2'],
#       dtype='object')

# %%
#Head and tail
movie.head()
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...

# %%
movie.tail(5)
# Out:
#          ID        City        Date   Season MatchNumber  \
# 945  335986     Kolkata  2008-04-20  2007/08           4
# 946  335985      Mumbai  2008-04-20  2007/08           5
# 947  335984       Delhi  2008-04-19  2007/08           3
# 948  335983  Chandigarh  2008-04-19  2007/08           2
# 949  335982   Bangalore  2008-04-18  2007/08           1
#
#                            Team1                        Team2  \
# 945        Kolkata Knight Riders              Deccan Chargers
# 946               Mumbai Indians  Royal Challengers Bangalore
# 947             Delhi Daredevils             Rajasthan Royals
# 948              Kings XI Punjab          Chennai Super Kings
# 949  Royal Challengers Bangalore        Kolkata Knight Riders
#
#                                           Venue                   TossWinner  \
# 945                                Eden Gardens              Deccan Chargers
# 946                            Wankhede Stadium               Mumbai Indians
# ...

# %%
movie.sample(5)
# Out:
#           ID         City        Date Season MatchNumber  \
# 249  1175360        Delhi  2019-03-26   2019           5
# 540   729303          NaN  2014-04-25   2014          13
# 453   829785    Bangalore  2015-05-06   2015          40
# 679   548321        Delhi  2012-04-19   2012          23
# 30   1304090  Navi Mumbai  2022-04-30   2022          44
#
#                            Team1                Team2  \
# 249               Delhi Capitals  Chennai Super Kings
# 540          Chennai Super Kings       Mumbai Indians
# 453  Royal Challengers Bangalore      Kings XI Punjab
# 679             Delhi Daredevils      Deccan Chargers
# 30              Rajasthan Royals       Mumbai Indians
#
#                                    Venue       TossWinner TossDecision  \
# 249                 Arun Jaitley Stadium   Delhi Capitals          bat
# 540  Dubai International Cricket Stadium   Mumbai Indians          bat
# 453                M Chinnaswamy Stadium  Kings XI Punjab        field
# ...

# %%
ipl = pd.read_csv("C:/Users/Om/Downloads/ipl-matches.csv")
ipl
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int64
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %%
ipl.describe()
# Out:
#                  ID      Margin
# count  9.500000e+02  932.000000
# mean   8.304852e+05   17.056867
# std    3.375678e+05   21.633109
# min    3.359820e+05    1.000000
# 25%    5.012612e+05    6.000000
# 50%    8.297380e+05    8.000000
# 75%    1.175372e+06   19.000000
# max    1.312200e+06  146.000000

# %%
#isnull
ipl.isnull().sum()
# Out:
# ID                   0
# City                51
# Date                 0
# Season               0
# MatchNumber          0
# Team1                0
# Team2                0
# Venue                0
# TossWinner           0
# TossDecision         0
# SuperOver            4
# WinningTeam          4
# WonBy                0
# Margin              18
# method             931
# Player_of_Match      4
# Team1Players         0
# Team2Players         0
# Umpire1              0
# Umpire2              0
# dtype: int64

# %%
#isduplicated

ipl.duplicated().sum()
# Out:
# np.int64(0)

# %%
ipl.rename(columns = {"Team1":"Team_1","Team2":"Team_2"},inplace = True)
ipl.columns
# Out:
# Index(['ID', 'City', 'Date', 'Season', 'MatchNumber', 'Team_1', 'Team_2',
#        'Venue', 'TossWinner', 'TossDecision', 'SuperOver', 'WinningTeam',
#        'WonBy', 'Margin', 'method', 'Player_of_Match', 'Team1Players',
#        'Team2Players', 'Umpire1', 'Umpire2'],
#       dtype='object')

# %%
#Math methods

student_data = [
    [100,80,10],
    [90,70,7],
    [120,100,14],
    [80,50,2]
]

student = pd.DataFrame(student_data,columns=['iq','marks','package'])
student
# Out:
#     iq  marks  package
# 0  100     80       10
# 1   90     70        7
# 2  120    100       14
# 3   80     50        2

# %%
student.sum(axis = 0)
# Out:
# iq         390
# marks      300
# package     33
# dtype: int64

# %%
student.mean(axis = 0)
# Out:
# iq         97.50
# marks      75.00
# package     8.25
# dtype: float64

# %%
#colums selection form dataframe
ipl['WinningTeam']
# Out:
# 0                   Gujarat Titans
# 1                 Rajasthan Royals
# 2      Royal Challengers Bangalore
# 3                   Gujarat Titans
# 4                     Punjab Kings
#                   ...
# 945          Kolkata Knight Riders
# 946    Royal Challengers Bangalore
# 947               Delhi Daredevils
# 948            Chennai Super Kings
# 949          Kolkata Knight Riders
# Name: WinningTeam, Length: 950, dtype: object

# %%
#multiple columns
ipl[['Team_1','Team_2','WinningTeam']]
# Out:
#                           Team_1                       Team_2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# 3               Rajasthan Royals               Gujarat Titans
# 4            Sunrisers Hyderabad                 Punjab Kings
# ..                           ...                          ...
# 945        Kolkata Knight Riders              Deccan Chargers
# 946               Mumbai Indians  Royal Challengers Bangalore
# 947             Delhi Daredevils             Rajasthan Royals
# 948              Kings XI Punjab          Chennai Super Kings
# 949  Royal Challengers Bangalore        Kolkata Knight Riders
#
#                      WinningTeam
# 0                 Gujarat Titans
# 1               Rajasthan Royals
# 2    Royal Challengers Bangalore
# 3                 Gujarat Titans
# 4                   Punjab Kings
# ...

# %%
#using iloc

ipl.iloc[1:6:]
# Out:
#         ID       City        Date Season  MatchNumber  \
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
# 5  1304115     Mumbai  2022-05-21   2022           69
#
#                         Team_1                Team_2  \
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
# 5               Delhi Capitals        Mumbai Indians
#
#                               Venue            TossWinner TossDecision  \
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# 3             Eden Gardens, Kolkata        Gujarat Titans        field
# ...

# %%
#fancing indexing

ipl.iloc[[0,2,4]]
# Out:
#         ID       City        Date Season MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022       Final
# 2  1312198    Kolkata  2022-05-25   2022  Eliminator
# 4  1304116     Mumbai  2022-05-22   2022          70
#
#                         Team_1                Team_2  \
# 0             Rajasthan Royals        Gujarat Titans
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# 4          Wankhede Stadium, Mumbai   Sunrisers Hyderabad          bat
#
#   SuperOver                  WinningTeam    WonBy  Margin method  \
# 0         N               Gujarat Titans  Wickets     7.0    NaN
# 2         N  Royal Challengers Bangalore     Runs    14.0    NaN
# ...

# %%
#using row and columns

ipl.iloc[0:6,0:3]
# Out:
#         ID       City        Date
# 0  1312200  Ahmedabad  2022-05-29
# 1  1312199  Ahmedabad  2022-05-27
# 2  1312198    Kolkata  2022-05-25
# 3  1312197    Kolkata  2022-05-24
# 4  1304116     Mumbai  2022-05-22
# 5  1304115     Mumbai  2022-05-21

# %%
ipl
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                           Team_1                       Team_2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
#data filtering

df = ipl[ipl['MatchNumber'] == 'Final']
df = df[['Season','MatchNumber','Team_1','Team_2','Venue']]
df
# Out:
#       Season MatchNumber                       Team_1  \
# 0       2022       Final             Rajasthan Royals
# 74      2021       Final          Chennai Super Kings
# 134  2020/21       Final               Delhi Capitals
# 194     2019       Final               Mumbai Indians
# 254     2018       Final          Sunrisers Hyderabad
# 314     2017       Final               Mumbai Indians
# 373     2016       Final  Royal Challengers Bangalore
# 433     2015       Final               Mumbai Indians
# 492     2014       Final        Kolkata Knight Riders
# 552     2013       Final          Chennai Super Kings
# 628     2012       Final        Kolkata Knight Riders
# 702     2011       Final          Chennai Super Kings
# 775  2009/10       Final          Chennai Super Kings
# 835     2009       Final  Royal Challengers Bangalore
# 892  2007/08       Final          Chennai Super Kings
#
#                           Team_2                                      Venue
# ...

# %%
student
# Out:
#     iq  marks  package
# 0  100     80       10
# 1   90     70        7
# 2  120    100       14
# 3   80     50        2

# %%
#Adding columns

student['Passing year'] = 2026
student
# Out:
#     iq  marks  package  Passing year
# 0  100     80       10          2026
# 1   90     70        7          2026
# 2  120    100       14          2026
# 3   80     50        2          2026

# %%
#From exisitng columns

student['Status'] = np.where(student['Passing year'] == 2026,"Passout",'Ongoing')
student
# Out:
#     iq  marks  package  Passing year   Status
# 0  100     80       10          2026  Passout
# 1   90     70        7          2026  Passout
# 2  120    100       14          2026  Passout
# 3   80     50        2          2026  Passout

# %%
#Handling null values
ipl.isnull().sum()
# Out:
# ID                   0
# City                51
# Date                 0
# Season               0
# MatchNumber          0
# Team_1               0
# Team_2               0
# Venue                0
# TossWinner           0
# TossDecision         0
# SuperOver            4
# WinningTeam          4
# WonBy                0
# Margin              18
# method             931
# Player_of_Match      4
# Team1Players         0
# Team2Players         0
# Umpire1              0
# Umpire2              0
# dtype: int64

# %%
ipl.dropna(inplace = True)

# %%
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19 entries, 282 to 910
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               19 non-null     int64
#  1   City             19 non-null     object
#  2   Date             19 non-null     object
#  3   Season           19 non-null     object
#  4   MatchNumber      19 non-null     object
#  5   Team_1           19 non-null     object
#  6   Team_2           19 non-null     object
#  7   Venue            19 non-null     object
#  8   TossWinner       19 non-null     object
#  9   TossDecision     19 non-null     object
#  10  SuperOver        19 non-null     object
#  11  WinningTeam      19 non-null     object
#  12  WonBy            19 non-null     object
#  13  Margin           19 non-null     float64
#  14  method           19 non-null     object
#  15  Player_of_Match  19 non-null     object
#  16  Team1Players     19 non-null     object
# ...

# %%
#Change of datatype

ipl['ID'] = ipl['ID'].astype('int32')
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19 entries, 282 to 910
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               19 non-null     int32
#  1   City             19 non-null     object
#  2   Date             19 non-null     object
#  3   Season           19 non-null     object
#  4   MatchNumber      19 non-null     object
#  5   Team_1           19 non-null     object
#  6   Team_2           19 non-null     object
#  7   Venue            19 non-null     object
#  8   TossWinner       19 non-null     object
#  9   TossDecision     19 non-null     object
#  10  SuperOver        19 non-null     object
#  11  WinningTeam      19 non-null     object
#  12  WonBy            19 non-null     object
#  13  Margin           19 non-null     float64
#  14  method           19 non-null     object
#  15  Player_of_Match  19 non-null     object
#  16  Team1Players     19 non-null     object
# ...
